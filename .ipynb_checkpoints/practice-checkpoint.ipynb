# %%
#5.1.10
# %matplotlib inline
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Load in csv
pyber_ride_df = pd.read_csv("Resources/PyBer_ride_data.csv")
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
#Plot x and y data using the plot() function
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
# Set x-axis and tick locations.
x_axis = np.arange(len(pyber_ride_df))
tick_locations = [value for value in x_axis]
# Plot the data.
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.xticks(tick_locations, pyber_ride_df["Month"])
plt.show()

# %%
#Create Bar Chart with same data
pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
#Create a bar chart by adding, "type, bar" to previous code
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.show()

# %%
import statistics

# %%
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
#Set the data
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
#Create a bar chart by adding, "type, bar" to previous code
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.show()
#Add error bars with caps
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize= 3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#Create a bar chart by adding, "type, bar" to previous code
pyber_ride_df.bar(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.show()
#Add error bars with caps
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize= 3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#Create a bar chart by adding, "type, bar" to previous code
pyber_ride_df.plot.barh(x="Month", y="Avg. Fare ($USD)")
plt.show(x_axis, y_axis)

# %%
#Create a bar chart by adding, "type, bar" to previous code
pyber_ride_df.plot.barh(x="Month", y="Avg. Fare ($USD)")
plt.show(x_axis, y_axis)

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
#Add error bars to the chart
plt.bar(x_axis, y_axis, yerr=stdev, capsize= 3, color= 'blue')
plt.yticks(np.arange(0, 51, step=5.0))
# Out:
# ([<matplotlib.axis.YTick at 0x117acb3d0>,
# ...
#  <a list of 11 Text yticklabel objects>)
